# %% [markdown]
# ## Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Graph

# %%
x = [1, 2, 3, 4, 5]
y = [5, 3, 6, 8, 4]

# %%
plt.plot(x, y)

plt.title('Example Graph')

plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.show()
